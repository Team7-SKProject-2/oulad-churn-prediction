# %% [markdown]
# # 03. 모델 실험
# Dummy, Logistic Regression, Random Forest, Boosting을 동일한 분할로 비교합니다. Test는 최종 선택 후 한 번만 평가합니다.

# %%
from pathlib import Path
import pandas as pd
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
# modeling_path = PROJECT_ROOT / 'data' / 'processed' / 'modeling_week2.csv'
# modeling = pd.read_csv(modeling_path)
